# %% [markdown]
# 何謂：Convolution Theorem？
# ANS：「迴積分定理」亦有譯為「迴旋積分定理」者，其主要應用為幫助 Laplace
# 積分反轉換之進行。其物理意義為兩函數經卷積運算後的傅立葉轉換等於函數個別傅立葉轉換的成積。

# %% [markdown]
# 證明：Convolution Theorem
#
# ![image.png](data:image/png;base64,...)
